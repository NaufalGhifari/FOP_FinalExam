# %% [markdown]
# # Fundamentals of Programming Exam
#
# Remember: This exam is intended for you to use Jupyter Notebook. Editing this file directly may make this file difficult for you to read.
#
# # Instructions
#
# 1.   This practice exam will be due on Tuesday 2nd of June, 2:00pm in Perth, Western Australia (+8 GMT)
# 2.   The exam is open book. You may use your notes, lecture slides, or other material.
# 3.   You are *not* to work together with any other student. All submissions will be checked for collusion.
# 4.   When submitting this, do so by renaming the Notebook file as your student number (i.e. 'FOP Practice Exam.ipynb' should become '9000000.ipynb')
# 5.   Any auxiliary files you might use should be archived as a .zip file alongside this notebook.

# %% [markdown]
# # Question One (25 marks)
#
# The code cell below creates a List and an Array.
#
# **(4 marks)**
# i) Python offers different mechanisms for looping. Discuss two of these and give an example of where you would use one over the other.
#
# **(3 marks)**
# ii) Create a function named *calcFactorial* that:
#
# *   Accepts an integer as a parameter
# *   Returns returns the factorial of that number
# *   Must **not** use functions such as math.factorial(). You must use control structures for this question.
# *   Note: The factorial of 0 is 1.
#
# **(8 marks)**
# iii) Create a function named *getInt* that:
# *   Accepts two integers as parameters: a lower and an upper bound.
# *   Asks the user for input. If the user input is lower than the lower bound or higher than the upper bound, the function must continue to ask the user for a new number.
# *   If the user enters in a non-numeric input, the program *must not crash*.
# *   The function must return this value as an integer.
#
# **(10 marks)**
# iv) Create a function named *calcSeries* that:
# *   Does not accept any parameters.
# *   The function will calculate the sum of the series given below:
#
# ![image.png](data:image/png;base64,...)
# *    ... where 'n' can by any number that a user enters.
# *    Recall that 'n!' is the notation for the factorial of n.
# *    For the purpose of this function, do not allow a user to enter negative values or numbers above 100.

# %% [markdown]
# ---
# **Q1 Part 1 may go here.**
#
# ---

# %%
# Attempt Q1 code here.

# %% [markdown]
# # Question Two (15 marks)
#
# For each of the following, describe what the code block does. Be very particular about the kinds of datatypes created. (Is it a list? Integer? Real number?)
#
# i) **(3 marks)**
# ```
# x = [str(y) for y in range(1,10) if x % 3 == 1]
# ```
#
# ii) **(2 marks)**
# ```
# f = open("data.csv","wb")
# ```
# iii) **(2 marks)**
# ```
# x = myArray[:, :-1]
# ```
#
# iv) **(8 marks)**
# ```
# import numpy as np
# dim = 1201
# data = np.fromfile(fn, np.dtype('>i2'), dim*dim).reshape((dim, dim))
# ```

# %% [markdown]
# ---
# Q2 Answers may go here.
#
# ---

# %% [markdown]
# # Question 3 (20 marks)
#
# This question will use the below code block for its tasks.
#
# In the mid-trimester test, you have seen that 'noise' can be added to an image to simulate issues with camera sensors. This issue is very common in real life applications, which is why there are many ways of countering the issue of noise. One simple method is what is known as 'mean smoothing', where we look at the area around a pixel and take the mean value of those neighbours.
#
# This helps to mitigate noise, but makes the image more blurry.
#
# The following image explains what is happening for each pixel.
#
# ![image.png](data:image/png;base64,...)
#
# Hint: Consider what you've done with calcHeat().
#
# Using the following code block, do the following:
# *   Finish blurImage() so that it performs mean smoothing for an area.
# *   Modify blurImage to raise an error when the result is less than 0 or greater than 255.
# *   Outside of blurImage, handle any errors that are raised and use the value of '0' for that particular result.
#
# You may wish to display the smoothed image to make sure your code is correct. Here is an example output:
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.misc
import random

# Performs smoothing over an area of an image.
def blurImage(img, r, c):
  result = 0 # Temporary value. Do something else!
  return result

# Function that will take an image and add random noise to it.
def imageNoise(face, chance): 
  rows,cols = face.shape

  for r in range(rows): # Iterating over rows
    for c in range(cols): # Iterating over columns
      num = random.random() # Random numimger imgetween 0 and 1
      if num < chance:
        face[r,c] = random.random()*255

  return face


face = scipy.misc.face(gray=True)
imageNoise(face, 0.20)

rows,cols = face.shape

plt.imshow(face, cmap=plt.cm.gray, interpolation='None')
plt.show()

# Because the smoothing performs its operation around a given pixel, we cannot
# start from 0 here. We start at 1 to prevent index out of bounds errors.

for r in range(1,rows-1): # Iterating over rows.
  for c in range(1,cols-1): # Iterating over columns
    face[r,c] = blurImage(face, r, c)

plt.imshow(face, cmap=plt.cm.gray, interpolation='None')
plt.show()

# %% [markdown]
# # Question 4 (10 marks)
#
# Copy your code from Question 1 to the code block below. Modify your code from to do the following:
#
# *   Create an **array** based on the user's input.
# *   Store each term in the series inside the above array (i.e. element 0 of the array will store 1/0!)
# *   Print out each term on the same line.

# %%
# Question Four Code goes here:

# %% [markdown]
# # Question 5 (10 marks)
#
# For the following UNIX shell script, use a meaningful example input to explain the purpose and any possible output.
#
# ```
# str=""
# for word in $*; do
#   if [ $word == "Snake" ]; then
#     str="Danger Noodle $str"
#   else
#     str="$word $str"
#   fi
# done
# echo $str
# ```

# %% [markdown]
# ---
#
# Answer Q5 here
#
# ---

# %% [markdown]
# # Question 6 (40 marks)
#
# Provided with this notebook is a file named *aircraft.csv*, which contains information on various aircraft types in the following format:
#
# ```
#  name, type, manufacturer, number of engines, [horsepower]
# ```
# *Note: horsepower is only provided for Rotary wing aircraft.*
#
# Each aircraft has a type, which can be one of two things: Rotary or Fixed. Helicopters are rotary wing aircraft, jet fighters and passenger lines are fixed wing aircraft. The given file will contain information about both, *however there are differences in the data depending on the type.*
#
# You may use the file as part of the tasks in the question.
#
# Good use of functions is required for full marks.
#
# **(5 marks)** i) Define a class that would be suitable for containing the information for each aircraft, but does not store information on Horsepower.
#
# **(10 marks)** ii) Define a class that represents a Rotary-wing aircraft.
# *   Rotary aircraft should inherit from your class made in part i) of this question.
# *   All rotary aircraft should have a variable representing maximum height, which will be set to 25,000.
# *   In addition to having information on horsepower, your Rotary class should also have a function called calcHorsepower(). This function simply multiplies the number of engines by the horsepower.
#
#
# **(5 marks)** iii) Define a Hangar class that will have a list of rotary and a list of fixed wing aircraft.
# *   This class will not inherit from anything, but will have a function that prints out the aircraft stored in its lists.
#
# **(20 marks)** iv) Write a program that will use the above class definitions to do the following:
# * Read a .csv file determined by user input (do not hardcode a value)
# * For this file, create a Hangar class
# * For each row in this file, create either an Aircraft class or a Rotary class to be stored in the appropriate list.
# * If a row contains invalid input (such as blank lines), skip that line without crashing the program. (Hint: use exception handling)
